# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from helper_functions.data_helper_functions import load_sector_metadata, extract_ceda_data
from helper_functions.lookup_helper_functions import lookup_value, lookup_sector_values, lookup_country_values, find_missing_values, batch_lookup, analyze_zeros_and_missing, find_zeros_by_country_sector
from helper_functions.missing_values import plot_zeros_per_country, plot_zeros_per_industry, list_missing_industries_by_country, print_missing_industries_report, export_missing_industries_to_csv
from helper_functions.null_masking import  convert_zeros_to_true_nulls, create_engineered_nulls, get_masked_values_df
from helper_functions.correlation_calc import match_countries, print_matching_report, calculate_correlations_optimized, rank_indicators_by_correlation, analyze_industry_specific_correlations, save_missing_countries

# %%
data_file_path = "data\Open CEDA by Watershed.xlsx"
metadata_file_path = "data\ceda_metadata.xlsx"

# %%
# Extract the CEDA data
ceda_data = extract_ceda_data(data_file_path)

if ceda_data is not None:
    print(f"Successfully extracted CEDA data with shape: {ceda_data.shape}")
    print("\nFirst few rows:")
    print(ceda_data.head())
    
    # Display column names (these might be sector codes)
    print("\nColumn names (potential sector codes):")
    print(ceda_data.columns.tolist()[:20])
# Out:
# Extracted data shape: (149, 402)
# Columns: ['Country Code', 'Country', '1111A0', '1111B0', '111200']...
# Successfully extracted CEDA data with shape: (149, 402)
#
# First few rows:
#   Country Code               Country    1111A0    1111B0    111200    111300  \
# 0          AFG           Afghanistan  0.832288  1.387533  0.597901  0.547433
# 1          AGO                Angola  0.507764  0.797831  0.378769  0.372152
# 2          ALB               Albania  0.647701  1.070358  0.455569  0.413583
# 3          ARE  United Arab Emirates  0.888452  1.466049  0.633348  0.581714
# 4          ARG             Argentina  0.810486  1.196029  0.565952  0.656380
#
#      111400    111900    112120    1121A0  ...    813B00    814000    S00500  \
# 0  0.746834  1.342802  1.587646  2.108243  ...  0.374271  0.283056  0.185664
# 1  0.450301  0.782578  0.920494  1.222898  ...  0.322642  0.212441  0.156688
# 2  0.578187  1.045690  1.216085  1.633651  ...  0.245527  0.240735  0.135756
# 3  0.777668  1.441345  1.667556  2.199879  ...  0.383058  0.285956  0.196644
# 4  0.815693  1.266295  1.683885  2.896392  ...  0.176149  0.516262  0.167227
#
#      S00600    491000    S00102     GSLGE     GSLGH     GSLGO    S00203
# 0  0.156771  0.238262  0.579318  0.264564  0.215760  0.198497  0.682814
# 1  0.128459  0.184608  0.551581  0.215822  0.174071  0.168488  0.450022
# 2  0.120999  0.189944  0.280341  0.193419  0.163231  0.147525  0.507389
# 3  0.165980  0.252867  0.556555  0.275595  0.230499  0.204042  0.713883
# 4  0.149618  0.183017  0.308733  0.261889  0.201041  0.272559  0.742574
#
# [5 rows x 402 columns]
#
# Column names (potential sector codes):
# ['Country Code', 'Country', '1111A0', '1111B0', '111200', '111300', '111400', '111900', '112120', '1121A0', '112300', '112A00', '113000', '114000', '115000', '211000', '212100', '212230', '2122A0', '212310']

# %%
# Test single value lookup
print("Testing single value lookup:")
value = lookup_value(ceda_data, 'Afghanistan', '1111A0')
print(f"Afghanistan, 1111A0: {value}")

# Test sector values across all countries
print("\nTesting sector values lookup:")
sector_values = lookup_sector_values(ceda_data, '1111A0')
if sector_values is not None:
    print(f"1111A0 values for first 5 countries:")
    print(sector_values.head())

# Test country values across all sectors
print("\nTesting country values lookup:")
country_values = lookup_country_values(ceda_data, 'Afghanistan')
if country_values is not None:
    print(f"Afghanistan values for first 10 sectors:")
    print(country_values.head(10))

# Find missing values
print("\nChecking for missing values:")
missing_info = find_missing_values(ceda_data)
print(f"Total missing values: {missing_info['total_missing']}")
print(f"Missing percentage: {missing_info['missing_percentage']:.2f}%")

if missing_info['total_missing'] > 0:
    print(f"\nMissing values per column (top 10):")
    print(missing_info['missing_per_column'].head(10))
    
    print(f"\nCountries with missing values (top 10):")
    print(missing_info['missing_per_country'].head(10))
# Out:
# Testing single value lookup:
# Afghanistan, 1111A0: 0.8322880914693332
#
# Testing sector values lookup:
# 1111A0 values for first 5 countries:
# Country
# Afghanistan             0.832288
# Angola                  0.507764
# Albania                 0.647701
# United Arab Emirates    0.888452
# Argentina               0.810486
# Name: 1111A0, dtype: float64
#
# Testing country values lookup:
# Afghanistan values for first 10 sectors:
# Country Code         AFG
# 1111A0          0.832288
# 1111B0          1.387533
# 111200          0.597901
# 111300          0.547433
# 111400          0.746834
# 111900          1.342802
# 112120          1.587646
# 1121A0          2.108243
# 112300          0.366549
# Name: Afghanistan, dtype: object
#
# Checking for missing values:
# Total missing values: 0
# Missing percentage: 0.00%

# %%
country_zeros = plot_zeros_per_country(ceda_data)

if country_zeros is not None:
    print(f"\nFound {len(country_zeros)} countries with zero values")
    print(f"Total zero values across all countries: {country_zeros['Zero_Count'].sum()}")
    print(f"\nTop 10 countries with most zeros:")
    print(country_zeros.head(10))

# Plot zeros per industry
industry_zeros = plot_zeros_per_industry(ceda_data)

if industry_zeros is not None:
    print(f"\nFound {len(industry_zeros)} industries with zero values")
    print(f"Total zero values across all industries: {industry_zeros['Zero_Count'].sum()}")
    print(f"\nTop 10 industries with most zeros:")
    print(industry_zeros.head(10))
# Out:
# Found 12 countries with zero values
# Total zero values across all countries: 63
#
# Top 10 countries with most zeros:
#              Country  Zero_Count
# 4   Hong Kong, China          17
# 1              Chile          15
# 7         Luxembourg           8
# 10         Singapore           8
# 8           Portugal           3
# 5           Cambodia           3
# 0            Belgium           3
# 11     United States           2
# 3         Costa Rica           1
# 2              China           1
# Found 41 industries with zero values
# Total zero values across all industries: 63
#
# Top 10 industries with most zeros:
#    Industry  Zero_Count
# 1    211000           6
# 7    213111           6
# 2    212100           6
# 40   814000           3
# 4    2122A0           2
# 6    2123A0           2
# 5    212310           2
# 8    21311A           2
# 3    212230           2
# 0    114000           1

# %%
summary_df, details_dict = list_missing_industries_by_country(ceda_data)

if summary_df is not None:
    # Print report
    print_missing_industries_report(summary_df, details_dict, show_details=True)
    
    # Export to CSV
    export_missing_industries_to_csv(summary_df, details_dict)
    
    # Get only top 10 countries with most missing industries
    top_summary, top_details = list_missing_industries_by_country(ceda_data, top_n=10)
    print("\n" + "="*80)
    print("TOP 10 COUNTRIES WITH MOST MISSING INDUSTRIES:")
    print_missing_industries_report(top_summary, top_details, show_details=True, max_industries_per_country=5)
    
    # You can also use the summary DataFrame for further analysis
    print("\n📈 Quick analysis of missing data distribution:")
    print(f"   • Countries with >50% missing: {len(summary_df[summary_df['Missing_Percentage'] > 50])}")
    print(f"   • Countries with >25% missing: {len(summary_df[summary_df['Missing_Percentage'] > 25])}")
    print(f"   • Countries with >10% missing: {len(summary_df[summary_df['Missing_Percentage'] > 10])}")
# Out:
# ================================================================================
# MISSING INDUSTRIES BY COUNTRY REPORT
# ================================================================================
#
# 📊 SUMMARY STATISTICS:
#    • Countries with missing data: 12
#    • Total missing industry entries: 63
#    • Average missing per country: 5.2
#    • Maximum missing in a country: 17
#    • Average missing percentage: 1.3%
#
# ================================================================================
# Country                   Missing Count   Missing %    Severity
# --------------------------------------------------------------------------------
# Hong Kong, China          17              4.2%       Low
# Chile                     15              3.7%       Low
# Luxembourg                8               2.0%       Low
# Singapore                 8               2.0%       Low
# Portugal                  3               0.7%       Low
# Cambodia                  3               0.7%       Low
# Belgium                   3               0.7%       Low
# United States             2               0.5%       Low
# Costa Rica                1               0.2%       Low
# China                     1               0.2%       Low
# South Korea               1               0.2%       Low
# Rest of World             1               0.2%       Low
#
# ================================================================================
# DETAILED MISSING INDUSTRIES BY COUNTRY:
# ================================================================================
#
# 📍 Belgium:
#    • Missing industries: 3 (0.7% of total)
#    • Industries: 211000, 212100, 213111
#
# 📍 Chile:
#    • Missing industries: 15 (3.7% of total)
#    • Industries (first 10 of 15):
#      336111, 336112, 336120, 336211, 336212, 336213, 336214, 336310, 336350, 336360
#      ... and 5 more
#
# 📍 China:
#    • Missing industries: 1 (0.2% of total)
#    • Industries: 814000
#
# 📍 Costa Rica:
#    • Missing industries: 1 (0.2% of total)
#    • Industries: 21311A
#
# 📍 Hong Kong, China:
#    • Missing industries: 17 (4.2% of total)
#    • Industries (first 10 of 17):
#      211000, 212100, 212230, 2122A0, 212310, 2123A0, 213111, 326110, 326120, 326130
#      ... and 7 more
#
# 📍 Cambodia:
#    • Missing industries: 3 (0.7% of total)
#    • Industries: 211000, 212100, 213111
#
# 📍 South Korea:
#    • Missing industries: 1 (0.2% of total)
#    • Industries: 811400
#
# 📍 Luxembourg:
#    • Missing industries: 8 (2.0% of total)
#    • Industries: 114000, 211000, 212100, 213111, 324110, 324121, 324122, 324190
#
# 📍 Portugal:
#    • Missing industries: 3 (0.7% of total)
#    • Industries: 211000, 212100, 213111
#
# 📍 Rest of World:
#    • Missing industries: 1 (0.2% of total)
#    • Industries: 814000
#
# 📍 Singapore:
#    • Missing industries: 8 (2.0% of total)
#    • Industries: 211000, 212100, 212230, 2122A0, 212310, 2123A0, 213111, 21311A
#
# 📍 United States:
#    • Missing industries: 2 (0.5% of total)
#    • Industries: 4200ID, 814000
#
# ================================================================================
# ✓ Summary exported to: missing_industries_summary.csv
# ✓ Detailed data exported to: missing_industries_detailed.csv
# ✓ Matrix format exported to: missing_industries_matrix.csv
#
# ================================================================================
# TOP 10 COUNTRIES WITH MOST MISSING INDUSTRIES:
# ================================================================================
# MISSING INDUSTRIES BY COUNTRY REPORT
# ================================================================================
#
# 📊 SUMMARY STATISTICS:
#    • Countries with missing data: 10
#    • Total missing industry entries: 61
#    • Average missing per country: 6.1
#    • Maximum missing in a country: 17
#    • Average missing percentage: 1.5%
#
# ================================================================================
# Country                   Missing Count   Missing %    Severity
# --------------------------------------------------------------------------------
# Hong Kong, China          17              4.2%       Low
# Chile                     15              3.7%       Low
# Luxembourg                8               2.0%       Low
# Singapore                 8               2.0%       Low
# Portugal                  3               0.7%       Low
# Cambodia                  3               0.7%       Low
# Belgium                   3               0.7%       Low
# United States             2               0.5%       Low
# Costa Rica                1               0.2%       Low
# China                     1               0.2%       Low
#
# ================================================================================
# DETAILED MISSING INDUSTRIES BY COUNTRY:
# ================================================================================
#
# 📍 Belgium:
#    • Missing industries: 3 (0.7% of total)
#    • Industries: 211000, 212100, 213111
#
# 📍 Chile:
#    • Missing industries: 15 (3.7% of total)
#    • Industries (first 5 of 15):
#      336111, 336112, 336120, 336211, 336212
#      ... and 10 more
#
# 📍 China:
#    • Missing industries: 1 (0.2% of total)
#    • Industries: 814000
#
# 📍 Costa Rica:
#    • Missing industries: 1 (0.2% of total)
#    • Industries: 21311A
#
# 📍 Hong Kong, China:
#    • Missing industries: 17 (4.2% of total)
#    • Industries (first 5 of 17):
#      211000, 212100, 212230, 2122A0, 212310
#      ... and 12 more
#
# 📍 Cambodia:
#    • Missing industries: 3 (0.7% of total)
#    • Industries: 211000, 212100, 213111
#
# 📍 Luxembourg:
#    • Missing industries: 8 (2.0% of total)
#    • Industries (first 5 of 8):
#      114000, 211000, 212100, 213111, 324110
#      ... and 3 more
#
# 📍 Portugal:
#    • Missing industries: 3 (0.7% of total)
#    • Industries: 211000, 212100, 213111
#
# 📍 Singapore:
#    • Missing industries: 8 (2.0% of total)
#    • Industries (first 5 of 8):
#      211000, 212100, 212230, 2122A0, 212310
#      ... and 3 more
#
# 📍 United States:
#    • Missing industries: 2 (0.5% of total)
#    • Industries: 4200ID, 814000
#
# ================================================================================
#
# 📈 Quick analysis of missing data distribution:
#    • Countries with >50% missing: 0
#    • Countries with >25% missing: 0
#    • Countries with >10% missing: 0

# %%
# Use each function separately as needed

# 1. Only convert 0s to NaN (if you just want to clean the database)
cleaned_df, stats = convert_zeros_to_true_nulls(ceda_data)
output_filename = f'ceda_cleaned.csv'
cleaned_df.to_csv(output_filename, index=False)

# 2. Only create engineered nulls (if data is already cleaned)
#    You can use this on any DataFrame, not just CEDA data
benchmark_df, mask_info = create_engineered_nulls(
    cleaned_df,
    null_percentage=0.15,  # 15% engineered nulls
    random_seed=123,
    exclude_columns=['Country', 'Region']  # List non-numeric columns to exclude
)
output_filename = f'ceda_masked_{mask_info["null_percentage"]*100:.0f}pct_seed{mask_info["random_seed"]}.csv'
benchmark_df.to_csv(output_filename, index=False)
print(f"Saved to: {output_filename}")

# 3. Get the masked values for evaluation reference
masked_values = get_masked_values_df(mask_info, cleaned_df)
# Out:
# Converting 0s to NaN (true database nulls)...
#   Converted 63 zeros to NaN
#   Original zeros: 0.11% of cells
#   New nulls: 0.11% of cells
# Creating engineered nulls (15.0% of non-null values)...
#   Total known values: 59,537
#   Added 8,930 engineered nulls
#   Original nulls: 63
#   Total nulls after masking: 8,993
#   Percentage of engineered nulls: 99.3%
# Saved to: ceda_masked_15pct_seed123.csv

# %%
if not masked_values.empty:
    masked_values.to_csv('masked_values_reference.csv', index=False)
    print("Saved masked values reference to: masked_values_reference.csv")
    
    # Show sample of masked values
    print("\nSample of masked values (first 5):")
    print(masked_values.head())

# Summary statistics
print("\n" + "=" * 60)
print("FINAL SUMMARY")
print("=" * 60)
print(f"Original data shape: {ceda_data.shape}")
print(f"True nulls (from database 0s): {stats['total_nulls_after']:,} cells")
print(f"Engineered nulls (for testing): {mask_info['engineered_nulls_count']:,} cells")
print(f"Total cells: {stats['total_cells']:,}")
print("\nMissing data percentages:")
print(f"  True database missing: {(stats['total_nulls_after']/stats['total_cells'])*100:.2f}%")
print(f"  After adding engineered: {(mask_info['total_nulls']/stats['total_cells'])*100:.2f}%")
# Out:
# Saved masked values reference to: masked_values_reference.csv
#
# Sample of masked values (first 5):
#            Country  Sector  Original_Value  Row_Index Column_Name
# 0          Burundi  322230        0.325224          8      322230
# 1          Finland  622000        0.115782         43      622000
# 2          Bahrain  33441A        1.013089         14      33441A
# 3  Slovak Republic  331410        0.939727        126      331410
# 4           Israel  532400        0.125859         66      532400
#
# ============================================================
# FINAL SUMMARY
# ============================================================
# Original data shape: (149, 402)
# True nulls (from database 0s): 63 cells
# Engineered nulls (for testing): 8,930 cells
# Total cells: 59,749
#
# Missing data percentages:
#   True database missing: 0.11%
#   After adding engineered: 15.05%

# %%
print("First 10 countries in original data:")
print(ceda_data['Country'].head(10).tolist())

print("\nFirst 10 countries in benchmark data:")
print(benchmark_df['Country'].head(10).tolist())
# Out:
# First 10 countries in original data:
# ['Afghanistan', 'Angola', 'Albania', 'United Arab Emirates', 'Argentina', 'Antigua and Barbuda', 'Australia', 'Austria', 'Burundi', 'Belgium']
#
# First 10 countries in benchmark data:
# ['Afghanistan', 'Angola', 'Albania', 'United Arab Emirates', 'Argentina', 'Antigua and Barbuda', 'Australia', 'Austria', 'Burundi', 'Belgium']

# %%
# Load datasets
indicators_df = pd.read_csv('country_indicator_latest_values.csv')
emissions_df = pd.read_csv('ceda_cleaned.csv')

print(f"Indicators dataset shape: {indicators_df.shape}")
print(f"Emissions dataset shape: {emissions_df.shape}")
print()

print("=== COLUMNS IN INDICATORS DATASET ===")
print(indicators_df.columns.tolist())
print()

print("=== COLUMNS IN EMISSIONS DATASET ===")
print(emissions_df.columns.tolist())
print()

# Look for country-related columns
print("=== SEARCHING FOR COUNTRY COLUMNS ===")
print("Indicators - columns containing 'country' or 'code':")
for col in indicators_df.columns:
    if any(term in col.lower() for term in ['country', 'code', 'iso', 'name', 'id']):
        print(f"  '{col}': First value = {indicators_df[col].iloc[0] if len(indicators_df) > 0 else 'N/A'}")
print()

print("Emissions - columns containing 'country' or 'code':")
for col in emissions_df.columns:
    if any(term in col.lower() for term in ['country', 'code', 'iso', 'name', 'id']):
        print(f"  '{col}': First value = {emissions_df[col].iloc[0] if len(emissions_df) > 0 else 'N/A'}")
# Out:
# Indicators dataset shape: (217, 11)
# Emissions dataset shape: (149, 402)
#
# === COLUMNS IN INDICATORS DATASET ===
# ['Country Name', 'Country Code', 'Fossil fuel energy consumption (% of total)', 'Energy use (kg of oil equivalent per capita)', 'GDP per capita, PPP (constant 2021 international $)', 'Manufacturing, value added (% of GDP)', 'Exports of goods and services (% of GDP)', 'Access to electricity (% of population)', 'Rail lines (total route-km)', 'Population, total', 'Urban population (% of total population)']
#
# === COLUMNS IN EMISSIONS DATASET ===
# ['Country', 'Country Code', '1111A0', '1111B0', '111200', '111300', '111400', '111900', '112120', '1121A0', '112300', '112A00', '113000', '114000', '115000', '211000', '212100', '212230', '2122A0', '212310', '2123A0', '213111', '21311A', '221100', '221200', '221300', '233210', '233262', '230301', '230302', '2332A0', '233412', '2334A0', '233230', '2332D0', '233240', '233411', '2332C0', '321100', '321200', '321910', '3219A0', '327100', '327200', '327310', '327320', '327330', '327390', '327400', '327910', '327991', '327992', '327993', '327999', '331110', '331200', '331313', '331410', '331420', '331490', '331510', '331520', '332114', '33211A', '332119', '332200', '332310', '332320', '332410', '332420', '332430', '332500', '332600', '332710', '332720', '332800', '332913', '33291A', '332991', '332996', '33299A', '332999', '333111', '333112', '333120', '333130', '333242', '33329A', '333314', '333316', '333318', '333414', '333415', '333413', '333511', '333514', '333517', '33351B', '333611', '333612', '333613', '333618', '333912', '333914', '333920', '333991', '333993', '333994', '33399A', '33399B', '334111', '334112', '334118', '334210', '334220', '334290', '334413', '334418', '33441A', '334510', '334511', '334512', '334513', '334514', '334515', '334516', '334517', '33451A', '334300', '334610', '335110', '335120', '335210', '335221', '335222', '335224', '335228', '335311', '335312', '335313', '335314', '335911', '335912', '335920', '335930', '335991', '335999', '336111', '336112', '336120', '336211', '336212', '336213', '336214', '336310', '336320', '336350', '336360', '336370', '336390', '3363A0', '336411', '336412', '336413', '336414', '33641A', '336500', '336611', '336612', '336991', '336992', '336999', '337110', '337121', '337122', '337127', '33712N', '337215', '33721A', '337900', '339112', '339113', '339114', '339115', '339116', '339910', '339920', '339930', '339940', '339950', '339990', '311111', '311119', '311210', '311221', '311225', '311224', '311230', '311300', '311410', '311420', '311513', '311514', '31151A', '311520', '311615', '31161A', '311700', '311810', '3118A0', '311910', '311920', '311930', '311940', '311990', '312110', '312120', '312130', '312140', '312200', '313100', '313200', '313300', '314110', '314120', '314900', '315000', '316000', '322110', '322120', '322130', '322210', '322220', '322230', '322291', '322299', '323110', '323120', '324110', '324121', '324122', '324190', '325110', '325120', '325130', '325180', '325190', '325211', '3252A0', '325411', '325412', '325413', '325414', '325310', '325320', '325510', '325520', '325610', '325620', '325910', '3259A0', '326110', '326120', '326130', '326140', '326150', '326160', '326190', '326210', '326220', '326290', '423100', '423400', '423600', '423800', '423A00', '424200', '424400', '424700', '424A00', '425000', '4200ID', '441000', '445000', '452000', '444000', '446000', '447000', '448000', '454000', '4B0000', '481000', '482000', '483000', '484000', '485000', '486000', '48A000', '492000', '493000', '511110', '511120', '511130', '5111A0', '511200', '512100', '512200', '515100', '515200', '517110', '517210', '517A00', '518200', '519130', '5191A0', '522A00', '52A000', '523900', '523A00', '524113', '5241XX', '524200', '525000', '531HSO', '531HST', '531ORE', '532100', '532400', '532A00', '533000', '541100', '541511', '541512', '54151A', '541200', '541300', '541610', '5416A0', '541700', '541800', '541400', '541920', '541940', '5419A0', '550000', '561300', '561700', '561100', '561200', '561400', '561500', '561600', '561900', '562000', '611100', '611A00', '611B00', '621100', '621200', '621300', '621400', '621500', '621600', '621900', '622000', '623A00', '623B00', '624100', '624400', '624A00', '711100', '711200', '711500', '711A00', '712000', '713100', '713200', '713900', '721000', '722110', '722211', '722A00', '811100', '811200', '811300', '811400', '812100', '812200', '812300', '812900', '813100', '813A00', '813B00', '814000', 'S00500', 'S00600', '491000', 'S00102', 'GSLGE', 'GS ...
#
# === SEARCHING FOR COUNTRY COLUMNS ===
# Indicators - columns containing 'country' or 'code':
#   'Country Name': First value = Afghanistan
#   'Country Code': First value = AFG
#
# Emissions - columns containing 'country' or 'code':
#   'Country': First value = Afghanistan
#   'Country Code': First value = AFG
#   '4200ID': First value = 0.1420574683065151

# %%
# Load datasets
indicators_df = pd.read_csv('country_indicator_latest_values.csv')
emissions_df = pd.read_csv('ceda_cleaned.csv')

print(f"Indicators dataset shape: {indicators_df.shape}")
print(f"Emissions (CEDA) dataset shape: {emissions_df.shape}")
print()

# Step 1: Match countries
print("Matching countries between datasets...")
matched_indicators, matched_emissions, match_stats = match_countries(
    indicators_df, 
    emissions_df,
    indicators_country_col='Country Code',    # Your actual column name
    emissions_country_col='Country Code',     # Your actual column name
    indicators_name_col='Country Name',       # Your actual column name
    emissions_name_col='Country'              # Your actual column name
)

# Print report focused on CEDA dataset
print_matching_report(match_stats, focus_on_ceda=True)
print()

# Save missing countries with both names and codes
filename, indicators_only_df, emissions_only_df = save_missing_countries(
    indicators_df, 
    emissions_df,
    indicators_country_col='Country Code',
    emissions_country_col='Country Code',
    indicators_name_col='Country Name',
    emissions_name_col='Country',
    filename="missing_countries_comprehensive.xlsx"
)

# Show preview of missing countries
print("\n📋 PREVIEW OF MISSING COUNTRIES:")
if len(emissions_only_df) > 0:
    print(f"\nTop 10 CEDA countries missing from indicators:")
    print(emissions_only_df.head(10).to_string(index=False))
    
if len(indicators_only_df) > 0:
    print(f"\nTop 10 indicator countries missing from CEDA:")
    print(indicators_only_df.head(10).to_string(index=False))

# Display matched countries count
print(f"\n✅ Matched countries available for correlation analysis: {match_stats['n_matched']}")
print(f"   • These countries will be used for correlation calculations")
print(f"   • Representing {match_stats['match_percentage_in_emissions']:.1f}% of CEDA dataset")

if match_stats['n_matched'] == 0:
    print("\n❌ No countries matched! Cannot calculate correlations.")
else:
    print(f"\n✅ Proceeding with {match_stats['n_matched']} matched countries for correlation analysis...")
    # Continue with correlation calculations
# Out:
#      Country Name Country Code  Fossil fuel energy consumption (% of total)  \
# 0     Afghanistan          AFG                                          NaN
# 1         Albania          ALB                                          0.0
# 2         Algeria          DZA                                          0.0
# 3  American Samoa          ASM                                          NaN
# 4         Andorra          AND                                          NaN
#
#    Energy use (kg of oil equivalent per capita)  \
# 0                                           NaN
# 1                                    888.463856
# 2                                   1503.414066
# 3                                           NaN
# 4                                           NaN
#
#    GDP per capita, PPP (constant 2021 international $)  \
# 0                                         1983.81262
# 1                                        21641.05315
# 2                                        15501.91970
# 3                                                NaN
# 4                                        65928.30720
#
#    Manufacturing, value added (% of GDP)  \
# 0                               7.540917
# 1                               6.505974
# 2                               9.454623
# 3                                    NaN
# 4                               3.397437
#
#    Exports of goods and services (% of GDP)  \
# 0                                 16.852788
# 1                                 36.284869
# 2                                 19.852380
# 3                                 46.957520
# 4                                       NaN
#
#    Access to electricity (% of population)  Rail lines (total route-km)  \
# 0                                     85.3                          NaN
# 1                                    100.0                          NaN
# 2                                    100.0                       4000.5
# 3                                      NaN                          NaN
# 4                                    100.0                          NaN
#
#    Population, total  Urban population (% of total population)
# 0         42647492.0                                 25.700735
# 1          2377128.0                                 58.546363
# 2         46814308.0                                 75.279291
# 3            46765.0                                 80.944699
# 4            81938.0                                 88.885004
#                 Country Country Code    1111A0    1111B0    111200    111300  \
# 0           Afghanistan          AFG  0.832288  1.387533  0.597901  0.547433
# 1                Angola          AGO  0.507764  0.797831  0.378769  0.372152
# 2               Albania          ALB  0.647701  1.070358  0.455569  0.413583
# 3  United Arab Emirates          ARE  0.888452  1.466049  0.633348  0.581714
# 4             Argentina          ARG  0.810486  1.196029  0.565952  0.656380
#
#      111400    111900    112120    1121A0  ...    813B00    814000    S00500  \
# 0  0.746834  1.342802  1.587646  2.108243  ...  0.374271  0.283056  0.185664
# 1  0.450301  0.782578  0.920494  1.222898  ...  0.322642  0.212441  0.156688
# 2  0.578187  1.045690  1.216085  1.633651  ...  0.245527  0.240735  0.135756
# 3  0.777668  1.441345  1.667556  2.199879  ...  0.383058  0.285956  0.196644
# 4  0.815693  1.266295  1.683885  2.896392  ...  0.176149  0.516262  0.167227
#
#      S00600    491000    S00102     GSLGE     GSLGH     GSLGO    S00203
# 0  0.156771  0.238262  0.579318  0.264564  0.215760  0.198497  0.682814
# 1  0.128459  0.184608  0.551581  0.215822  0.174071  0.168488  0.450022
# 2  0.120999  0.189944  0.280341  0.193419  0.163231  0.147525  0.507389
# 3  0.165980  0.252867  0.556555  0.275595  0.230499  0.204042  0.713883
# 4  0.149618  0.183017  0.308733  0.261889  0.201041  0.272559  0.742574
#
# [5 rows x 402 columns]
# Indicators dataset shape: (217, 11)
# Emissions (CEDA) dataset shape: (149, 402)
#
# Matching countries between datasets...
# Indicators columns: ['Country Name', 'Country Code', 'Fossil fuel energy consumption (% of total)', 'Energy use (kg of oil equivalent per capita)', 'GDP per capita, PPP (constant 2021 international $)']...
# Emissions columns: ['Country', 'Country Code', '1111A0', '1111B0', '111200']...
#
# Sample indicators country codes (before cleaning):
# ['AFG', 'ALB', 'DZA', 'ASM', 'AND', 'AGO', 'ATG', 'ARG', 'ARM', 'ABW']
#
# Sample emissions country codes (before cleaning):
# ['AFG', 'AGO', 'ALB', 'ARE', 'ARG', 'ATG', 'AUS', 'AUT', 'BDI', 'BEL']
#
# Sample indicators country codes (after cleaning):
# ['AFG', 'ALB', 'DZA', 'ASM', 'AND', 'AGO', 'ATG', 'ARG', 'ARM', 'ABW']
#
# Sample emissions country codes (after cleaning):
# ['AFG', 'AGO', 'ALB', 'ARE', 'ARG', 'ATG', 'AUS', 'AUT', 'BDI', 'BEL']
# ================================================================================
# COUNTRY MATCHING REPORT
# ================================================================================
#
# 📊 FOCUS ON CEDA DATASET:
#    • Countries in CEDA dataset: 149
#    • CEDA countries matched with indicators: 147
#    • CEDA coverage by indicators: 98.7%
#    • CEDA countries NOT in indicators: 2
#
# 📍 CEDA Countries missing from indicators:
#     1. ROW - Rest of World
#     2. TWN - Chinese Taipei
#
# 📈 MATCHING EFFICIENCY:
#    • CEDA dataset coverage: 98.7%
#    ✅ Good: High coverage of CEDA dataset (≥80%)
#
# 🔍 ANALYSIS:
#    • Indicators dataset has more unique countries (+68)
#
# ================================================================================
#
# ✓ Country comparison exported to: missing_countries_comprehensive.xlsx
#    • Summary sheet: Overall statistics
#    • Only_In_Indicators: 70 countries only in indicators
#    • Only_In_Emissions: 2 countries only in emissions
#
# 📋 PREVIEW OF MISSING COUNTRIES:
#
# Top 10 CEDA countries missing from indicators:
# Country_Code   Country_Name
#          ROW  Rest of World
#          TWN Chinese Taipei
#
# Top 10 indicator countries missing from CEDA:
# Country_Code           Country_Name
#          ABW                  Aruba
#          AND                Andorra
#          ARM                Armenia
#          ASM         American Samoa
#          AZE             Azerbaijan
#          BIH Bosnia and Herzegovina
#          BLR                Belarus
#          BMU                Bermuda
#          BRN      Brunei Darussalam
#          BWA               Botswana
#
# ✅ Matched countries available for correlation analysis: 147
#    • These countries will be used for correlation calculations
#    • Representing 98.7% of CEDA dataset
#
# ✅ Proceeding with 147 matched countries for correlation analysis...

# %%
# Step 2: Calculate correlations
print("Calculating correlations between indicators and industry emissions...")
correlation_df = calculate_correlations_optimized(
    matched_indicators, 
    matched_emissions,
    indicators_country_col='Country Code',    # Your actual column name
    emissions_country_col='Country Code',     # Your actual column name
    indicators_name_col='Country Name',       # Your actual column name
    emissions_name_col='Country'              # Your actual column name
)
# Out:
# Calculating correlations between indicators and industry emissions...
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# ...
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:2999: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\ryank\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\lib\_function_base_impl.py:3000: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]

# %%
# Step 3: Rank indicators by average correlation across industries
print("TOP 20 INDICATORS BY AVERAGE ABSOLUTE CORRELATION:")
print("=" * 80)
indicator_rankings = rank_indicators_by_correlation(correlation_df, top_n=20)

for idx, (indicator, row) in enumerate(indicator_rankings.iterrows(), 1):
    avg_corr = row['Correlation']
    avg_abs_corr = row['Abs_Correlation']
    n_industries = row['N_Industries']
    direction = "positive" if avg_corr > 0 else "negative"
    
    print(f"{idx:2d}. {indicator:50s} | Avg correlation: {avg_corr:+.3f} ({direction})")
    print(f"    {'':50s}   Avg absolute: {avg_abs_corr:.3f} | Industries: {n_industries}")
print()
# Out:
# TOP 20 INDICATORS BY AVERAGE ABSOLUTE CORRELATION:
# ================================================================================
#  1. Population, total                                  | Avg correlation: +0.226 (positive)
#                                                          Avg absolute: 0.228 | Industries: 400.0
#  2. Access to electricity (% of population)            | Avg correlation: +0.200 (positive)
#                                                          Avg absolute: 0.200 | Industries: 400.0
#  3. Rail lines (total route-km)                        | Avg correlation: +0.191 (positive)
#                                                          Avg absolute: 0.193 | Industries: 400.0
#  4. GDP per capita, PPP (constant 2021 international $) | Avg correlation: -0.102 (negative)
#                                                          Avg absolute: 0.129 | Industries: 400.0
#  5. Energy use (kg of oil equivalent per capita)       | Avg correlation: +0.126 (positive)
#                                                          Avg absolute: 0.127 | Industries: 400.0
#  6. Manufacturing, value added (% of GDP)              | Avg correlation: +0.099 (positive)
#                                                          Avg absolute: 0.102 | Industries: 400.0
#  7. Urban population (% of total population)           | Avg correlation: +0.015 (positive)
#                                                          Avg absolute: 0.076 | Industries: 400.0
#  8. Exports of goods and services (% of GDP)           | Avg correlation: +0.036 (positive)
#                                                          Avg absolute: 0.067 | Industries: 400.0
#  9. Fossil fuel energy consumption (% of total)        | Avg correlation: +nan (negative)
#                                                          Avg absolute: nan | Industries: 400.0

# %%
# Step 4: Show industry-specific top correlations
print("INDUSTRY-SPECIFIC TOP CORRELATIONS:")
print("=" * 80)
industry_analysis = analyze_industry_specific_correlations(correlation_df, top_per_industry=3)

for industry, results in industry_analysis.items():
    print(f"\nIndustry: {industry}")
    print(f"Total indicators analyzed: {results['n_indicators']}")
    
    print("  Top positive correlations:")
    for _, row in results['top_positive'].iterrows():
        print(f"    - {row['Indicator']}: {row['Correlation']:.3f} (n={row['N_Countries']})")
    
    print("  Top negative correlations:")
    for _, row in results['top_negative'].iterrows():
        print(f"    - {row['Indicator']}: {row['Correlation']:.3f} (n={row['N_Countries']})")

# Optional: Save results to files
print("\nSaving results to files...")
correlation_df.to_csv('all_correlations.csv', index=False)
indicator_rankings.to_csv('indicator_rankings.csv')

# Save industry-specific results
with pd.ExcelWriter('industry_specific_correlations.xlsx') as writer:
    for industry, results in industry_analysis.items():
        # Combine positive and negative
        combined = pd.concat([
            results['top_positive'].assign(Type='Positive'),
            results['top_negative'].assign(Type='Negative')
        ])
        combined.to_excel(writer, sheet_name=industry[:31], index=False)

print("Analysis complete! Files saved:")
print("  - all_correlations.csv: All individual correlations")
print("  - indicator_rankings.csv: Top indicators by average correlation")
print("  - industry_specific_correlations.xlsx: Top correlations per industry")
# Out:
# INDUSTRY-SPECIFIC TOP CORRELATIONS:
# ================================================================================
#
# Industry: 1111A0
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.226 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.213 (n=117)
#     - Urban population (% of total population): 0.105 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.055 (n=147)
#     - Exports of goods and services (% of GDP): -0.046 (n=133)
#     - Population, total: -0.028 (n=147)
#
# Industry: 1111B0
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Energy use (kg of oil equivalent per capita): 0.180 (n=117)
#     - Access to electricity (% of population): 0.177 (n=147)
#     - Rail lines (total route-km): 0.074 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.109 (n=147)
#     - Exports of goods and services (% of GDP): -0.084 (n=133)
#     - Manufacturing, value added (% of GDP): -0.069 (n=145)
#
# Industry: 111200
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.259 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.237 (n=117)
#     - Rail lines (total route-km): 0.153 (n=54)
#   Top negative correlations:
#     - Exports of goods and services (% of GDP): -0.007 (n=133)
#     - GDP per capita, PPP (constant 2021 international $): 0.001 (n=147)
#     - Manufacturing, value added (% of GDP): 0.024 (n=145)
#
# Industry: 111300
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.337 (n=147)
#     - Rail lines (total route-km): 0.292 (n=54)
#     - Energy use (kg of oil equivalent per capita): 0.251 (n=117)
#   Top negative correlations:
#     - Exports of goods and services (% of GDP): 0.067 (n=133)
#     - Manufacturing, value added (% of GDP): 0.089 (n=145)
#     - GDP per capita, PPP (constant 2021 international $): 0.110 (n=147)
#
# Industry: 111400
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.239 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.212 (n=117)
#     - Urban population (% of total population): 0.127 (n=147)
#   Top negative correlations:
#     - Population, total: -0.049 (n=147)
#     - Exports of goods and services (% of GDP): -0.024 (n=133)
#     - Manufacturing, value added (% of GDP): -0.023 (n=145)
#
# Industry: 111900
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.206 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.190 (n=117)
#     - Rail lines (total route-km): 0.093 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.083 (n=147)
#     - Exports of goods and services (% of GDP): -0.064 (n=133)
#     - Manufacturing, value added (% of GDP): -0.055 (n=145)
#
# Industry: 112120
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.220 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.199 (n=117)
#     - Rail lines (total route-km): 0.119 (n=54)
#   Top negative correlations:
#     - Exports of goods and services (% of GDP): -0.072 (n=133)
#     - GDP per capita, PPP (constant 2021 international $): -0.048 (n=147)
#     - Manufacturing, value added (% of GDP): -0.041 (n=145)
#
# Industry: 1121A0
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.260 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.225 (n=117)
#     - Rail lines (total route-km): 0.158 (n=54)
#   Top negative correlations:
#     - Exports of goods and services (% of GDP): -0.053 (n=133)
#     - Population, total: -0.002 (n=147)
#     - Manufacturing, value added (% of GDP): 0.001 (n=145)
#
# Industry: 112300
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.311 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.274 (n=117)
#     - Rail lines (total route-km): 0.254 (n=54)
#   Top negative correlations:
#     - Exports of goods and services (% of GDP): 0.020 (n=133)
#     - Population, total: 0.026 (n=147)
#     - Manufacturing, value added (% of GDP): 0.049 (n=145)
#
# Industry: 112A00
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.302 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.242 (n=117)
#     - Rail lines (total route-km): 0.238 (n=54)
#   Top negative correlations:
#     - Exports of goods and services (% of GDP): -0.005 (n=133)
#     - Manufacturing, value added (% of GDP): 0.057 (n=145)
#     - GDP per capita, PPP (constant 2021 international $): 0.064 (n=147)
#
# Industry: 113000
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.334 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.282 (n=117)
#     - Urban population (% of total population): 0.257 (n=147)
#   Top negative correlations:
#     - Population, total: 0.028 (n=147)
#     - Exports of goods and services (% of GDP): 0.113 (n=133)
#     - Manufacturing, value added (% of GDP): 0.143 (n=145)
#
# Industry: 114000
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.306 (n=146)
#     - Urban population (% of total population): 0.303 (n=146)
#     - Energy use (kg of oil equivalent per capita): 0.278 (n=116)
#   Top negative correlations:
#     - Population, total: -0.095 (n=146)
#     - Rail lines (total route-km): -0.077 (n=53)
#     - Manufacturing, value added (% of GDP): 0.029 (n=144)
#
# Industry: 115000
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.356 (n=147)
#     - Urban population (% of total population): 0.250 (n=147)
#     - Rail lines (total route-km): 0.243 (n=54)
#   Top negative correlations:
#     - Exports of goods and services (% of GDP): 0.126 (n=133)
#     - Population, total: 0.160 (n=147)
#     - GDP per capita, PPP (constant 2021 international $): 0.174 (n=147)
#
# Industry: 211000
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.299 (n=141)
#     - Urban population (% of total population): 0.195 (n=141)
#     - Energy use (kg of oil equivalent per capita): 0.172 (n=111)
#   Top negative correlations:
#     - Rail lines (total route-km): -0.025 (n=50)
#     - Population, total: 0.002 (n=141)
#     - Manufacturing, value added (% of GDP): 0.037 (n=139)
#
# Industry: 212100
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.277 (n=141)
#     - Urban population (% of total population): 0.237 (n=141)
#     - GDP per capita, PPP (constant 2021 international $): 0.145 (n=141)
#   Top negative correlations:
#     - Rail lines (total route-km): -0.051 (n=50)
#     - Population, total: -0.016 (n=141)
#     - Manufacturing, value added (% of GDP): 0.061 (n=139)
#
# Industry: 212230
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.241 (n=145)
#     - Energy use (kg of oil equivalent per capita): 0.094 (n=115)
#     - Exports of goods and services (% of GDP): 0.087 (n=131)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.095 (n=145)
#     - Population, total: 0.027 (n=145)
#     - Rail lines (total route-km): 0.037 (n=53)
#
# Industry: 2122A0
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.253 (n=145)
#     - Exports of goods and services (% of GDP): 0.103 (n=131)
#     - Energy use (kg of oil equivalent per capita): 0.103 (n=115)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.080 (n=145)
#     - Population, total: 0.049 (n=145)
#     - Urban population (% of total population): 0.052 (n=145)
#
# Industry: 212310
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.233 (n=145)
#     - Population, total: 0.178 (n=145)
#     - Manufacturing, value added (% of GDP): 0.148 (n=143)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.085 (n=145)
#     - Urban population (% of total population): 0.001 (n=145)
#     - Energy use (kg of oil equivalent per capita): 0.101 (n=115)
#
# Industry: 2123A0
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.240 (n=145)
#     - Exports of goods and services (% of GDP): 0.112 (n=131)
#     - Population, total: 0.111 (n=145)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.095 (n=145)
#     - Urban population (% of total population): 0.031 (n=145)
#     - Rail lines (total route-km): 0.087 (n=53)
#
# Industry: 213111
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Exports of goods and services (% of GDP): 0.449 (n=127)
#     - GDP per capita, PPP (constant 2021 international $): 0.300 (n=141)
#     - Access to electricity (% of population): 0.283 (n=141)
#   Top negative correlations:
#     - Rail lines (total route-km): -0.067 (n=50)
#     - Population, total: 0.061 (n=141)
#     - Energy use (kg of oil equivalent per capita): 0.063 (n=111)
#
# Industry: 21311A
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.190 (n=145)
#     - Population, total: 0.174 (n=145)
#     - Rail lines (total route-km): 0.174 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.116 (n=145)
#     - Urban population (% of total population): 0.007 (n=145)
#     - Energy use (kg of oil equivalent per capita): 0.052 (n=115)
#
# Industry: 221100
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Energy use (kg of oil equivalent per capita): 0.266 (n=117)
#     - Population, total: 0.195 (n=147)
#     - Access to electricity (% of population): 0.180 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): 0.034 (n=147)
#     - Exports of goods and services (% of GDP): 0.049 (n=133)
#     - Urban population (% of total population): 0.137 (n=147)
#
# Industry: 221200
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.198 (n=147)
#     - Manufacturing, value added (% of GDP): 0.090 (n=145)
#     - Population, total: 0.087 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.103 (n=147)
#     - Exports of goods and services (% of GDP): -0.017 (n=133)
#     - Urban population (% of total population): 0.049 (n=147)
#
# Industry: 221300
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Energy use (kg of oil equivalent per capita): 0.242 (n=117)
#     - Access to electricity (% of population): 0.223 (n=147)
#     - Rail lines (total route-km): 0.137 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.125 (n=147)
#     - Exports of goods and services (% of GDP): -0.059 (n=133)
#     - Population, total: 0.054 (n=147)
#
# Industry: 233210
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.268 (n=147)
#     - Rail lines (total route-km): 0.197 (n=54)
#     - Manufacturing, value added (% of GDP): 0.144 (n=145)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.297 (n=147)
#     - Urban population (% of total population): -0.150 (n=147)
#     - Exports of goods and services (% of GDP): -0.087 (n=133)
#
# Industry: 233262
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.238 (n=147)
#     - Rail lines (total route-km): 0.186 (n=54)
#     - Manufacturing, value added (% of GDP): 0.114 (n=145)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.329 (n=147)
#     - Urban population (% of total population): -0.172 (n=147)
#     - Exports of goods and services (% of GDP): -0.101 (n=133)
#
# Industry: 230301
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.146 (n=147)
#     - Manufacturing, value added (% of GDP): 0.140 (n=145)
#     - Population, total: 0.139 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.284 (n=147)
#     - Urban population (% of total population): -0.113 (n=147)
#     - Exports of goods and services (% of GDP): -0.099 (n=133)
#
# Industry: 230302
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.246 (n=147)
#     - Rail lines (total route-km): 0.201 (n=54)
#     - Access to electricity (% of population): 0.114 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.312 (n=147)
#     - Urban population (% of total population): -0.140 (n=147)
#     - Exports of goods and services (% of GDP): -0.094 (n=133)
#
# Industry: 2332A0
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.247 (n=147)
#     - Rail lines (total route-km): 0.227 (n=54)
#     - Manufacturing, value added (% of GDP): 0.141 (n=145)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.272 (n=147)
#     - Urban population (% of total population): -0.127 (n=147)
#     - Exports of goods and services (% of GDP): -0.078 (n=133)
#
# Industry: 233412
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.303 (n=147)
#     - Rail lines (total route-km): 0.196 (n=54)
#     - Manufacturing, value added (% of GDP): 0.147 (n=145)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.339 (n=147)
#     - Urban population (% of total population): -0.162 (n=147)
#     - Exports of goods and services (% of GDP): -0.122 (n=133)
#
# Industry: 2334A0
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.248 (n=147)
#     - Rail lines (total route-km): 0.201 (n=54)
#     - Manufacturing, value added (% of GDP): 0.135 (n=145)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.303 (n=147)
#     - Urban population (% of total population): -0.135 (n=147)
#     - Exports of goods and services (% of GDP): -0.114 (n=133)
#
# Industry: 233230
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.177 (n=147)
#     - Manufacturing, value added (% of GDP): 0.150 (n=145)
#     - Rail lines (total route-km): 0.128 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.308 (n=147)
#     - Urban population (% of total population): -0.156 (n=147)
#     - Exports of goods and services (% of GDP): -0.095 (n=133)
#
# Industry: 2332D0
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.196 (n=147)
#     - Manufacturing, value added (% of GDP): 0.161 (n=145)
#     - Access to electricity (% of population): 0.139 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.312 (n=147)
#     - Urban population (% of total population): -0.138 (n=147)
#     - Exports of goods and services (% of GDP): -0.118 (n=133)
#
# Industry: 233240
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.261 (n=147)
#     - Rail lines (total route-km): 0.171 (n=54)
#     - Manufacturing, value added (% of GDP): 0.143 (n=145)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.327 (n=147)
#     - Urban population (% of total population): -0.152 (n=147)
#     - Exports of goods and services (% of GDP): -0.117 (n=133)
#
# Industry: 233411
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.350 (n=147)
#     - Rail lines (total route-km): 0.259 (n=54)
#     - Manufacturing, value added (% of GDP): 0.193 (n=145)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.254 (n=147)
#     - Urban population (% of total population): -0.107 (n=147)
#     - Exports of goods and services (% of GDP): -0.072 (n=133)
#
# Industry: 2332C0
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.160 (n=147)
#     - Rail lines (total route-km): 0.128 (n=54)
#     - Manufacturing, value added (% of GDP): 0.100 (n=145)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.341 (n=147)
#     - Urban population (% of total population): -0.162 (n=147)
#     - Exports of goods and services (% of GDP): -0.114 (n=133)
#
# Industry: 321100
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Rail lines (total route-km): 0.260 (n=54)
#     - Energy use (kg of oil equivalent per capita): 0.245 (n=117)
#     - Access to electricity (% of population): 0.198 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.017 (n=147)
#     - Exports of goods and services (% of GDP): 0.029 (n=133)
#     - Population, total: 0.093 (n=147)
#
# Industry: 321200
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Rail lines (total route-km): 0.311 (n=54)
#     - Energy use (kg of oil equivalent per capita): 0.245 (n=117)
#     - Access to electricity (% of population): 0.193 (n=147)
#   Top negative correlations:
#     - Exports of goods and services (% of GDP): -0.053 (n=133)
#     - GDP per capita, PPP (constant 2021 international $): -0.008 (n=147)
#     - Population, total: 0.084 (n=147)
#
# Industry: 321910
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Rail lines (total route-km): 0.289 (n=54)
#     - Energy use (kg of oil equivalent per capita): 0.247 (n=117)
#     - Access to electricity (% of population): 0.236 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): 0.014 (n=147)
#     - Exports of goods and services (% of GDP): 0.040 (n=133)
#     - Urban population (% of total population): 0.118 (n=147)
#
# Industry: 3219A0
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Rail lines (total route-km): 0.291 (n=54)
#     - Access to electricity (% of population): 0.259 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.229 (n=117)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): 0.029 (n=147)
#     - Exports of goods and services (% of GDP): 0.037 (n=133)
#     - Urban population (% of total population): 0.122 (n=147)
#
# Industry: 327100
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.166 (n=147)
#     - Access to electricity (% of population): 0.160 (n=147)
#     - Rail lines (total route-km): 0.128 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.220 (n=147)
#     - Urban population (% of total population): -0.023 (n=147)
#     - Exports of goods and services (% of GDP): -0.017 (n=133)
#
# Industry: 327200
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.145 (n=147)
#     - Rail lines (total route-km): 0.130 (n=54)
#     - Population, total: 0.129 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.241 (n=147)
#     - Urban population (% of total population): -0.041 (n=147)
#     - Exports of goods and services (% of GDP): -0.040 (n=133)
#
# Industry: 327310
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.200 (n=147)
#     - Manufacturing, value added (% of GDP): 0.074 (n=145)
#     - Energy use (kg of oil equivalent per capita): 0.066 (n=117)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.186 (n=147)
#     - Exports of goods and services (% of GDP): -0.034 (n=133)
#     - Rail lines (total route-km): -0.032 (n=54)
#
# Industry: 327320
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.126 (n=147)
#     - Rail lines (total route-km): 0.106 (n=54)
#     - Access to electricity (% of population): 0.089 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.289 (n=147)
#     - Exports of goods and services (% of GDP): -0.069 (n=133)
#     - Urban population (% of total population): -0.064 (n=147)
#
# Industry: 327330
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.226 (n=147)
#     - Rail lines (total route-km): 0.184 (n=54)
#     - Access to electricity (% of population): 0.165 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.196 (n=147)
#     - Urban population (% of total population): -0.013 (n=147)
#     - Exports of goods and services (% of GDP): 0.002 (n=133)
#
# Industry: 327390
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.165 (n=147)
#     - Rail lines (total route-km): 0.133 (n=54)
#     - Access to electricity (% of population): 0.124 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.247 (n=147)
#     - Urban population (% of total population): -0.062 (n=147)
#     - Exports of goods and services (% of GDP): -0.004 (n=133)
#
# Industry: 327400
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.184 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.092 (n=117)
#     - Manufacturing, value added (% of GDP): 0.058 (n=145)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.227 (n=147)
#     - Exports of goods and services (% of GDP): -0.091 (n=133)
#     - Urban population (% of total population): -0.021 (n=147)
#
# Industry: 327910
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.226 (n=147)
#     - Rail lines (total route-km): 0.205 (n=54)
#     - Energy use (kg of oil equivalent per capita): 0.124 (n=117)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.232 (n=147)
#     - Urban population (% of total population): -0.068 (n=147)
#     - Exports of goods and services (% of GDP): -0.017 (n=133)
#
# Industry: 327991
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.375 (n=147)
#     - Rail lines (total route-km): 0.344 (n=54)
#     - Access to electricity (% of population): 0.119 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.199 (n=147)
#     - Urban population (% of total population): -0.062 (n=147)
#     - Exports of goods and services (% of GDP): 0.033 (n=133)
#
# Industry: 327992
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.216 (n=147)
#     - Access to electricity (% of population): 0.214 (n=147)
#     - Rail lines (total route-km): 0.169 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.135 (n=147)
#     - Urban population (% of total population): 0.032 (n=147)
#     - Exports of goods and services (% of GDP): 0.033 (n=133)
#
# Industry: 327993
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Energy use (kg of oil equivalent per capita): 0.131 (n=117)
#     - Access to electricity (% of population): 0.115 (n=147)
#     - Rail lines (total route-km): 0.074 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.249 (n=147)
#     - Exports of goods and services (% of GDP): -0.065 (n=133)
#     - Urban population (% of total population): -0.049 (n=147)
#
# Industry: 327999
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.093 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.039 (n=117)
#     - Rail lines (total route-km): 0.034 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.275 (n=147)
#     - Urban population (% of total population): -0.062 (n=147)
#     - Manufacturing, value added (% of GDP): -0.025 (n=145)
#
# Industry: 331110
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.386 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.231 (n=117)
#     - Urban population (% of total population): 0.226 (n=147)
#   Top negative correlations:
#     - Rail lines (total route-km): -0.098 (n=54)
#     - Population, total: 0.044 (n=147)
#     - Manufacturing, value added (% of GDP): 0.126 (n=145)
#
# Industry: 331200
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.289 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.168 (n=117)
#     - Urban population (% of total population): 0.152 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): 0.014 (n=147)
#     - Rail lines (total route-km): 0.077 (n=54)
#     - Manufacturing, value added (% of GDP): 0.091 (n=145)
#
# Industry: 331313
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Rail lines (total route-km): 0.356 (n=54)
#     - Population, total: 0.340 (n=147)
#     - Access to electricity (% of population): 0.264 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): 0.013 (n=147)
#     - Exports of goods and services (% of GDP): 0.038 (n=133)
#     - Manufacturing, value added (% of GDP): 0.100 (n=145)
#
# Industry: 331410
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Energy use (kg of oil equivalent per capita): 0.180 (n=117)
#     - Access to electricity (% of population): 0.155 (n=147)
#     - Rail lines (total route-km): 0.114 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.136 (n=147)
#     - Exports of goods and services (% of GDP): -0.023 (n=133)
#     - Urban population (% of total population): 0.027 (n=147)
#
# Industry: 331420
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Rail lines (total route-km): 0.264 (n=54)
#     - Energy use (kg of oil equivalent per capita): 0.258 (n=117)
#     - Access to electricity (% of population): 0.248 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.001 (n=147)
#     - Exports of goods and services (% of GDP): 0.047 (n=133)
#     - Manufacturing, value added (% of GDP): 0.075 (n=145)
#
# Industry: 331490
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.282 (n=147)
#     - Rail lines (total route-km): 0.195 (n=54)
#     - Energy use (kg of oil equivalent per capita): 0.193 (n=117)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): 0.031 (n=147)
#     - Exports of goods and services (% of GDP): 0.054 (n=133)
#     - Manufacturing, value added (% of GDP): 0.101 (n=145)
#
# Industry: 331510
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.352 (n=147)
#     - Rail lines (total route-km): 0.263 (n=54)
#     - Access to electricity (% of population): 0.260 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): 0.026 (n=147)
#     - Exports of goods and services (% of GDP): 0.080 (n=133)
#     - Urban population (% of total population): 0.133 (n=147)
#
# Industry: 331520
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.333 (n=147)
#     - Rail lines (total route-km): 0.277 (n=54)
#     - Access to electricity (% of population): 0.232 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.036 (n=147)
#     - Exports of goods and services (% of GDP): 0.024 (n=133)
#     - Urban population (% of total population): 0.088 (n=147)
#
# Industry: 332114
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.386 (n=147)
#     - Urban population (% of total population): 0.276 (n=147)
#     - GDP per capita, PPP (constant 2021 international $): 0.271 (n=147)
#   Top negative correlations:
#     - Rail lines (total route-km): 0.105 (n=54)
#     - Population, total: 0.150 (n=147)
#     - Manufacturing, value added (% of GDP): 0.172 (n=145)
#
# Industry: 33211A
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.355 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.220 (n=117)
#     - Urban population (% of total population): 0.208 (n=147)
#   Top negative correlations:
#     - Rail lines (total route-km): 0.073 (n=54)
#     - Population, total: 0.109 (n=147)
#     - Manufacturing, value added (% of GDP): 0.129 (n=145)
#
# Industry: 332119
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.239 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.134 (n=117)
#     - Population, total: 0.130 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.068 (n=147)
#     - Urban population (% of total population): 0.074 (n=147)
#     - Manufacturing, value added (% of GDP): 0.078 (n=145)
#
# Industry: 332200
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.272 (n=147)
#     - Access to electricity (% of population): 0.255 (n=147)
#     - Rail lines (total route-km): 0.170 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.062 (n=147)
#     - Urban population (% of total population): 0.063 (n=147)
#     - Exports of goods and services (% of GDP): 0.120 (n=133)
#
# Industry: 332310
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.263 (n=147)
#     - Population, total: 0.232 (n=147)
#     - Rail lines (total route-km): 0.185 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.032 (n=147)
#     - Exports of goods and services (% of GDP): 0.085 (n=133)
#     - Manufacturing, value added (% of GDP): 0.096 (n=145)
#
# Industry: 332320
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.271 (n=147)
#     - Access to electricity (% of population): 0.247 (n=147)
#     - Rail lines (total route-km): 0.234 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.062 (n=147)
#     - Urban population (% of total population): 0.072 (n=147)
#     - Exports of goods and services (% of GDP): 0.094 (n=133)
#
# Industry: 332410
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.237 (n=147)
#     - Population, total: 0.221 (n=147)
#     - Rail lines (total route-km): 0.164 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.079 (n=147)
#     - Urban population (% of total population): 0.047 (n=147)
#     - Manufacturing, value added (% of GDP): 0.082 (n=145)
#
# Industry: 332420
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.265 (n=147)
#     - Access to electricity (% of population): 0.261 (n=147)
#     - Rail lines (total route-km): 0.199 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.023 (n=147)
#     - Urban population (% of total population): 0.092 (n=147)
#     - Exports of goods and services (% of GDP): 0.093 (n=133)
#
# Industry: 332430
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Rail lines (total route-km): 0.260 (n=54)
#     - Population, total: 0.255 (n=147)
#     - Access to electricity (% of population): 0.199 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.140 (n=147)
#     - Urban population (% of total population): 0.015 (n=147)
#     - Exports of goods and services (% of GDP): 0.026 (n=133)
#
# Industry: 332500
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.288 (n=147)
#     - Rail lines (total route-km): 0.236 (n=54)
#     - Access to electricity (% of population): 0.233 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.075 (n=147)
#     - Urban population (% of total population): 0.050 (n=147)
#     - Exports of goods and services (% of GDP): 0.098 (n=133)
#
# Industry: 332600
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.250 (n=147)
#     - Population, total: 0.163 (n=147)
#     - Rail lines (total route-km): 0.156 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.045 (n=147)
#     - Urban population (% of total population): 0.092 (n=147)
#     - Manufacturing, value added (% of GDP): 0.109 (n=145)
#
# Industry: 332710
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.260 (n=147)
#     - Rail lines (total route-km): 0.193 (n=54)
#     - Access to electricity (% of population): 0.170 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.186 (n=147)
#     - Urban population (% of total population): -0.017 (n=147)
#     - Exports of goods and services (% of GDP): 0.036 (n=133)
#
# Industry: 332720
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.265 (n=147)
#     - Rail lines (total route-km): 0.226 (n=54)
#     - Access to electricity (% of population): 0.213 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.110 (n=147)
#     - Urban population (% of total population): 0.046 (n=147)
#     - Exports of goods and services (% of GDP): 0.056 (n=133)
#
# Industry: 332800
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.223 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.152 (n=117)
#     - Population, total: 0.148 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.084 (n=147)
#     - Exports of goods and services (% of GDP): 0.061 (n=133)
#     - Urban population (% of total population): 0.070 (n=147)
#
# Industry: 332913
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Rail lines (total route-km): 0.237 (n=54)
#     - Population, total: 0.207 (n=147)
#     - Access to electricity (% of population): 0.180 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.162 (n=147)
#     - Urban population (% of total population): -0.021 (n=147)
#     - Manufacturing, value added (% of GDP): 0.060 (n=145)
#
# Industry: 33291A
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.220 (n=147)
#     - Access to electricity (% of population): 0.200 (n=147)
#     - Rail lines (total route-km): 0.153 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.148 (n=147)
#     - Urban population (% of total population): 0.013 (n=147)
#     - Exports of goods and services (% of GDP): 0.058 (n=133)
#
# Industry: 332991
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.270 (n=147)
#     - Rail lines (total route-km): 0.179 (n=54)
#     - Access to electricity (% of population): 0.151 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.212 (n=147)
#     - Urban population (% of total population): -0.039 (n=147)
#     - Exports of goods and services (% of GDP): -0.002 (n=133)
#
# Industry: 332996
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.297 (n=147)
#     - Population, total: 0.201 (n=147)
#     - Exports of goods and services (% of GDP): 0.157 (n=133)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): 0.001 (n=147)
#     - Rail lines (total route-km): 0.085 (n=54)
#     - Manufacturing, value added (% of GDP): 0.103 (n=145)
#
# Industry: 33299A
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.224 (n=147)
#     - Rail lines (total route-km): 0.198 (n=54)
#     - Access to electricity (% of population): 0.169 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.198 (n=147)
#     - Urban population (% of total population): -0.028 (n=147)
#     - Exports of goods and services (% of GDP): 0.037 (n=133)
#
# Industry: 332999
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.283 (n=147)
#     - Access to electricity (% of population): 0.247 (n=147)
#     - Rail lines (total route-km): 0.242 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.086 (n=147)
#     - Exports of goods and services (% of GDP): 0.043 (n=133)
#     - Urban population (% of total population): 0.066 (n=147)
#
# Industry: 333111
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.272 (n=147)
#     - Access to electricity (% of population): 0.266 (n=147)
#     - Rail lines (total route-km): 0.214 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.053 (n=147)
#     - Exports of goods and services (% of GDP): 0.052 (n=133)
#     - Urban population (% of total population): 0.081 (n=147)
#
# Industry: 333112
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.372 (n=147)
#     - Rail lines (total route-km): 0.287 (n=54)
#     - Access to electricity (% of population): 0.216 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.127 (n=147)
#     - Urban population (% of total population): 0.011 (n=147)
#     - Exports of goods and services (% of GDP): 0.029 (n=133)
#
# Industry: 333120
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.266 (n=147)
#     - Population, total: 0.221 (n=147)
#     - Rail lines (total route-km): 0.158 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.063 (n=147)
#     - Exports of goods and services (% of GDP): 0.054 (n=133)
#     - Urban population (% of total population): 0.064 (n=147)
#
# Industry: 333130
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.270 (n=147)
#     - Population, total: 0.254 (n=147)
#     - Rail lines (total route-km): 0.186 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.057 (n=147)
#     - Exports of goods and services (% of GDP): 0.042 (n=133)
#     - Manufacturing, value added (% of GDP): 0.059 (n=145)
#
# Industry: 333242
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.400 (n=147)
#     - Rail lines (total route-km): 0.278 (n=54)
#     - Access to electricity (% of population): 0.196 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.143 (n=147)
#     - Urban population (% of total population): -0.015 (n=147)
#     - Exports of goods and services (% of GDP): 0.036 (n=133)
#
# Industry: 33329A
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.366 (n=147)
#     - Rail lines (total route-km): 0.298 (n=54)
#     - Access to electricity (% of population): 0.201 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.149 (n=147)
#     - Urban population (% of total population): -0.008 (n=147)
#     - Exports of goods and services (% of GDP): 0.004 (n=133)
#
# Industry: 333314
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.497 (n=147)
#     - Rail lines (total route-km): 0.259 (n=54)
#     - Access to electricity (% of population): 0.082 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.258 (n=147)
#     - Urban population (% of total population): -0.143 (n=147)
#     - Exports of goods and services (% of GDP): -0.026 (n=133)
#
# Industry: 333316
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.164 (n=147)
#     - Access to electricity (% of population): 0.118 (n=147)
#     - Rail lines (total route-km): 0.106 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.282 (n=147)
#     - Urban population (% of total population): -0.123 (n=147)
#     - Manufacturing, value added (% of GDP): -0.042 (n=145)
#
# Industry: 333318
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Rail lines (total route-km): 0.285 (n=54)
#     - Population, total: 0.256 (n=147)
#     - Access to electricity (% of population): 0.237 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): 0.034 (n=147)
#     - Exports of goods and services (% of GDP): 0.037 (n=133)
#     - Urban population (% of total population): 0.080 (n=147)
#
# Industry: 333414
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.256 (n=147)
#     - Access to electricity (% of population): 0.214 (n=147)
#     - Rail lines (total route-km): 0.210 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.110 (n=147)
#     - Exports of goods and services (% of GDP): 0.019 (n=133)
#     - Manufacturing, value added (% of GDP): 0.029 (n=145)
#
# Industry: 333415
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Rail lines (total route-km): 0.304 (n=54)
#     - Population, total: 0.276 (n=147)
#     - Access to electricity (% of population): 0.233 (n=147)
#   Top negative correlations:
#     - Exports of goods and services (% of GDP): 0.042 (n=133)
#     - GDP per capita, PPP (constant 2021 international $): 0.050 (n=147)
#     - Urban population (% of total population): 0.095 (n=147)
#
# Industry: 333413
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.389 (n=147)
#     - Rail lines (total route-km): 0.307 (n=54)
#     - Access to electricity (% of population): 0.227 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.096 (n=147)
#     - Exports of goods and services (% of GDP): 0.027 (n=133)
#     - Urban population (% of total population): 0.042 (n=147)
#
# Industry: 333511
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.309 (n=147)
#     - Rail lines (total route-km): 0.216 (n=54)
#     - Access to electricity (% of population): 0.206 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.124 (n=147)
#     - Exports of goods and services (% of GDP): 0.001 (n=133)
#     - Urban population (% of total population): 0.024 (n=147)
#
# Industry: 333514
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.248 (n=147)
#     - Access to electricity (% of population): 0.177 (n=147)
#     - Rail lines (total route-km): 0.167 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.188 (n=147)
#     - Urban population (% of total population): -0.020 (n=147)
#     - Exports of goods and services (% of GDP): -0.008 (n=133)
#
# Industry: 333517
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.338 (n=147)
#     - Rail lines (total route-km): 0.235 (n=54)
#     - Access to electricity (% of population): 0.232 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.108 (n=147)
#     - Exports of goods and services (% of GDP): 0.022 (n=133)
#     - Urban population (% of total population): 0.035 (n=147)
#
# Industry: 33351B
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.388 (n=147)
#     - Rail lines (total route-km): 0.279 (n=54)
#     - Access to electricity (% of population): 0.209 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.118 (n=147)
#     - Exports of goods and services (% of GDP): -0.030 (n=133)
#     - Urban population (% of total population): 0.021 (n=147)
#
# Industry: 333611
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.330 (n=147)
#     - Rail lines (total route-km): 0.261 (n=54)
#     - Access to electricity (% of population): 0.230 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.081 (n=147)
#     - Urban population (% of total population): 0.039 (n=147)
#     - Exports of goods and services (% of GDP): 0.046 (n=133)
#
# Industry: 333612
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.317 (n=147)
#     - Rail lines (total route-km): 0.228 (n=54)
#     - Access to electricity (% of population): 0.195 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.151 (n=147)
#     - Urban population (% of total population): -0.011 (n=147)
#     - Exports of goods and services (% of GDP): 0.007 (n=133)
#
# Industry: 333613
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.328 (n=147)
#     - Rail lines (total route-km): 0.237 (n=54)
#     - Access to electricity (% of population): 0.224 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.090 (n=147)
#     - Exports of goods and services (% of GDP): 0.014 (n=133)
#     - Urban population (% of total population): 0.038 (n=147)
#
# Industry: 333618
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.298 (n=147)
#     - Rail lines (total route-km): 0.270 (n=54)
#     - Access to electricity (% of population): 0.203 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.152 (n=147)
#     - Urban population (% of total population): -0.000 (n=147)
#     - Exports of goods and services (% of GDP): 0.011 (n=133)
#
# Industry: 333912
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.320 (n=147)
#     - Rail lines (total route-km): 0.279 (n=54)
#     - Access to electricity (% of population): 0.212 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.147 (n=147)
#     - Urban population (% of total population): 0.001 (n=147)
#     - Exports of goods and services (% of GDP): 0.019 (n=133)
#
# Industry: 333914
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.313 (n=147)
#     - Rail lines (total route-km): 0.252 (n=54)
#     - Access to electricity (% of population): 0.200 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.166 (n=147)
#     - Urban population (% of total population): -0.020 (n=147)
#     - Exports of goods and services (% of GDP): 0.014 (n=133)
#
# Industry: 333920
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.259 (n=147)
#     - Population, total: 0.223 (n=147)
#     - Rail lines (total route-km): 0.153 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.042 (n=147)
#     - Manufacturing, value added (% of GDP): 0.037 (n=145)
#     - Exports of goods and services (% of GDP): 0.062 (n=133)
#
# Industry: 333991
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.278 (n=147)
#     - Access to electricity (% of population): 0.222 (n=147)
#     - Rail lines (total route-km): 0.192 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.121 (n=147)
#     - Urban population (% of total population): 0.030 (n=147)
#     - Manufacturing, value added (% of GDP): 0.030 (n=145)
#
# Industry: 333993
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.367 (n=147)
#     - Rail lines (total route-km): 0.253 (n=54)
#     - Access to electricity (% of population): 0.214 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.140 (n=147)
#     - Urban population (% of total population): -0.016 (n=147)
#     - Exports of goods and services (% of GDP): 0.052 (n=133)
# ...
#     - Urban population (% of total population): -0.087 (n=147)
#     - Exports of goods and services (% of GDP): -0.052 (n=133)
#
# Industry: 624400
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Rail lines (total route-km): 0.284 (n=54)
#     - Manufacturing, value added (% of GDP): 0.252 (n=145)
#     - Population, total: 0.237 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.037 (n=147)
#     - Urban population (% of total population): -0.004 (n=147)
#     - Exports of goods and services (% of GDP): 0.022 (n=133)
#
# Industry: 624A00
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.210 (n=147)
#     - Manufacturing, value added (% of GDP): 0.196 (n=145)
#     - Population, total: 0.154 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.077 (n=147)
#     - Exports of goods and services (% of GDP): -0.017 (n=133)
#     - Urban population (% of total population): -0.007 (n=147)
#
# Industry: 711100
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.454 (n=147)
#     - Rail lines (total route-km): 0.359 (n=54)
#     - Manufacturing, value added (% of GDP): 0.125 (n=145)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.230 (n=147)
#     - Urban population (% of total population): -0.143 (n=147)
#     - Exports of goods and services (% of GDP): -0.031 (n=133)
#
# Industry: 711200
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.218 (n=147)
#     - Rail lines (total route-km): 0.148 (n=54)
#     - Access to electricity (% of population): 0.077 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.244 (n=147)
#     - Urban population (% of total population): -0.164 (n=147)
#     - Exports of goods and services (% of GDP): -0.024 (n=133)
#
# Industry: 711500
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.532 (n=147)
#     - Rail lines (total route-km): 0.378 (n=54)
#     - Manufacturing, value added (% of GDP): 0.119 (n=145)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.229 (n=147)
#     - Urban population (% of total population): -0.158 (n=147)
#     - Exports of goods and services (% of GDP): 0.003 (n=133)
#
# Industry: 711A00
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Energy use (kg of oil equivalent per capita): 0.103 (n=117)
#     - Population, total: 0.103 (n=147)
#     - Access to electricity (% of population): 0.062 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.227 (n=147)
#     - Urban population (% of total population): -0.145 (n=147)
#     - Exports of goods and services (% of GDP): -0.006 (n=133)
#
# Industry: 712000
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.271 (n=147)
#     - Rail lines (total route-km): 0.224 (n=54)
#     - Access to electricity (% of population): 0.126 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.180 (n=147)
#     - Urban population (% of total population): -0.109 (n=147)
#     - Exports of goods and services (% of GDP): 0.002 (n=133)
#
# Industry: 713100
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.191 (n=147)
#     - Rail lines (total route-km): 0.181 (n=54)
#     - Access to electricity (% of population): 0.141 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.143 (n=147)
#     - Urban population (% of total population): -0.065 (n=147)
#     - Manufacturing, value added (% of GDP): 0.027 (n=145)
#
# Industry: 713200
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.173 (n=147)
#     - Population, total: 0.133 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.086 (n=117)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.221 (n=147)
#     - Urban population (% of total population): -0.096 (n=147)
#     - Exports of goods and services (% of GDP): 0.006 (n=133)
#
# Industry: 713900
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.166 (n=147)
#     - Access to electricity (% of population): 0.154 (n=147)
#     - Rail lines (total route-km): 0.152 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.143 (n=147)
#     - Urban population (% of total population): -0.064 (n=147)
#     - Exports of goods and services (% of GDP): 0.013 (n=133)
#
# Industry: 721000
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.262 (n=147)
#     - Access to electricity (% of population): 0.252 (n=147)
#     - Rail lines (total route-km): 0.242 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.019 (n=147)
#     - Urban population (% of total population): 0.081 (n=147)
#     - Exports of goods and services (% of GDP): 0.096 (n=133)
#
# Industry: 722110
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.272 (n=147)
#     - Manufacturing, value added (% of GDP): 0.248 (n=145)
#     - Population, total: 0.202 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.022 (n=147)
#     - Urban population (% of total population): 0.091 (n=147)
#     - Exports of goods and services (% of GDP): 0.094 (n=133)
#
# Industry: 722211
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.295 (n=147)
#     - Rail lines (total route-km): 0.251 (n=54)
#     - Manufacturing, value added (% of GDP): 0.223 (n=145)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): 0.020 (n=147)
#     - Urban population (% of total population): 0.117 (n=147)
#     - Exports of goods and services (% of GDP): 0.132 (n=133)
#
# Industry: 722A00
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.337 (n=147)
#     - Rail lines (total route-km): 0.274 (n=54)
#     - Manufacturing, value added (% of GDP): 0.253 (n=145)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.023 (n=147)
#     - Urban population (% of total population): 0.050 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.119 (n=117)
#
# Industry: 811100
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.399 (n=147)
#     - Rail lines (total route-km): 0.336 (n=54)
#     - Manufacturing, value added (% of GDP): 0.260 (n=145)
#   Top negative correlations:
#     - Urban population (% of total population): 0.160 (n=147)
#     - GDP per capita, PPP (constant 2021 international $): 0.164 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.170 (n=117)
#
# Industry: 811200
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.273 (n=147)
#     - Rail lines (total route-km): 0.204 (n=54)
#     - Energy use (kg of oil equivalent per capita): 0.118 (n=117)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.257 (n=147)
#     - Urban population (% of total population): -0.080 (n=147)
#     - Exports of goods and services (% of GDP): -0.061 (n=133)
#
# Industry: 811300
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.227 (n=147)
#     - Rail lines (total route-km): 0.156 (n=54)
#     - Energy use (kg of oil equivalent per capita): 0.119 (n=117)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.262 (n=147)
#     - Exports of goods and services (% of GDP): -0.087 (n=133)
#     - Urban population (% of total population): -0.073 (n=147)
#
# Industry: 811400
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.413 (n=146)
#     - Rail lines (total route-km): 0.293 (n=53)
#     - Access to electricity (% of population): 0.199 (n=146)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.050 (n=146)
#     - Urban population (% of total population): -0.009 (n=146)
#     - Energy use (kg of oil equivalent per capita): 0.045 (n=116)
#
# Industry: 812100
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.401 (n=147)
#     - Rail lines (total route-km): 0.270 (n=54)
#     - Access to electricity (% of population): 0.195 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.043 (n=147)
#     - Urban population (% of total population): -0.036 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.041 (n=117)
#
# Industry: 812200
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.218 (n=147)
#     - Manufacturing, value added (% of GDP): 0.195 (n=145)
#     - Population, total: 0.180 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.117 (n=147)
#     - Urban population (% of total population): 0.000 (n=147)
#     - Energy use (kg of oil equivalent per capita): 0.040 (n=117)
#
# Industry: 812300
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.278 (n=147)
#     - Access to electricity (% of population): 0.195 (n=147)
#     - Rail lines (total route-km): 0.192 (n=54)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.010 (n=147)
#     - Exports of goods and services (% of GDP): 0.016 (n=133)
#     - Urban population (% of total population): 0.025 (n=147)
#
# Industry: 812900
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.356 (n=147)
#     - Rail lines (total route-km): 0.210 (n=54)
#     - Access to electricity (% of population): 0.188 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.180 (n=147)
#     - Urban population (% of total population): -0.075 (n=147)
#     - Exports of goods and services (% of GDP): 0.009 (n=133)
#
# Industry: 813100
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.192 (n=147)
#     - Manufacturing, value added (% of GDP): 0.170 (n=145)
#     - Population, total: 0.102 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.167 (n=147)
#     - Urban population (% of total population): -0.055 (n=147)
#     - Exports of goods and services (% of GDP): -0.024 (n=133)
#
# Industry: 813A00
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Population, total: 0.169 (n=147)
#     - Manufacturing, value added (% of GDP): 0.161 (n=145)
#     - Access to electricity (% of population): 0.139 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.201 (n=147)
#     - Urban population (% of total population): -0.123 (n=147)
#     - Exports of goods and services (% of GDP): -0.037 (n=133)
#
# Industry: 813B00
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.169 (n=147)
#     - Manufacturing, value added (% of GDP): 0.162 (n=145)
#     - Population, total: 0.155 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.166 (n=147)
#     - Urban population (% of total population): -0.059 (n=147)
#     - Exports of goods and services (% of GDP): -0.011 (n=133)
#
# Industry: 814000
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.258 (n=145)
#     - Rail lines (total route-km): 0.219 (n=52)
#     - Urban population (% of total population): 0.131 (n=145)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): 0.019 (n=145)
#     - Population, total: 0.056 (n=145)
#     - Energy use (kg of oil equivalent per capita): 0.093 (n=115)
#
# Industry: S00500
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Rail lines (total route-km): 0.243 (n=54)
#     - Population, total: 0.239 (n=147)
#     - Manufacturing, value added (% of GDP): 0.203 (n=145)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.073 (n=147)
#     - Urban population (% of total population): -0.047 (n=147)
#     - Exports of goods and services (% of GDP): 0.047 (n=133)
#
# Industry: S00600
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Manufacturing, value added (% of GDP): 0.202 (n=145)
#     - Population, total: 0.173 (n=147)
#     - Access to electricity (% of population): 0.151 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.151 (n=147)
#     - Urban population (% of total population): -0.079 (n=147)
#     - Exports of goods and services (% of GDP): 0.029 (n=133)
#
# Industry: 491000
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Exports of goods and services (% of GDP): 0.244 (n=133)
#     - Access to electricity (% of population): 0.227 (n=147)
#     - Population, total: 0.157 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): 0.059 (n=147)
#     - Manufacturing, value added (% of GDP): 0.082 (n=145)
#     - Rail lines (total route-km): 0.115 (n=54)
#
# Industry: S00102
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Rail lines (total route-km): 0.201 (n=54)
#     - Access to electricity (% of population): 0.127 (n=147)
#     - Population, total: 0.120 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.125 (n=147)
#     - Urban population (% of total population): -0.053 (n=147)
#     - Exports of goods and services (% of GDP): -0.013 (n=133)
#
# Industry: GSLGE
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Rail lines (total route-km): 0.245 (n=54)
#     - Access to electricity (% of population): 0.195 (n=147)
#     - Manufacturing, value added (% of GDP): 0.172 (n=145)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.079 (n=147)
#     - Urban population (% of total population): -0.004 (n=147)
#     - Exports of goods and services (% of GDP): -0.001 (n=133)
#
# Industry: GSLGH
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Rail lines (total route-km): 0.220 (n=54)
#     - Access to electricity (% of population): 0.204 (n=147)
#     - Manufacturing, value added (% of GDP): 0.198 (n=145)
#   Top negative correlations:
#     - Exports of goods and services (% of GDP): -0.023 (n=133)
#     - GDP per capita, PPP (constant 2021 international $): -0.018 (n=147)
#     - Urban population (% of total population): 0.044 (n=147)
#
# Industry: GSLGO
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Rail lines (total route-km): 0.296 (n=54)
#     - Manufacturing, value added (% of GDP): 0.260 (n=145)
#     - Access to electricity (% of population): 0.204 (n=147)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): 0.006 (n=147)
#     - Exports of goods and services (% of GDP): 0.023 (n=133)
#     - Urban population (% of total population): 0.046 (n=147)
#
# Industry: S00203
# Total indicators analyzed: 9
#   Top positive correlations:
#     - Access to electricity (% of population): 0.213 (n=147)
#     - Manufacturing, value added (% of GDP): 0.176 (n=145)
#     - Energy use (kg of oil equivalent per capita): 0.068 (n=117)
#   Top negative correlations:
#     - GDP per capita, PPP (constant 2021 international $): -0.109 (n=147)
#     - Population, total: -0.000 (n=147)
#     - Exports of goods and services (% of GDP): 0.003 (n=133)
#
# Saving results to files...
# Analysis complete! Files saved:
#   - all_correlations.csv: All individual correlations
#   - indicator_rankings.csv: Top indicators by average correlation
#   - industry_specific_correlations.xlsx: Top correlations per industry
